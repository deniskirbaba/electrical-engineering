# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
u = np.array([18.99, 18.987, 18.981, 18.962, 18.905, 18.812, 18.627, 18.095, 17.273, 15.833, 12.667, 9.5, 0])
i = np.array([0.001899, 0.0025316, 0.0037962, 0.0075848, 0.018905, 0.037624, 0.074508, 0.18095, 0.34546, 0.63332, 1.2667, 1.9, 3.8328])

# %%
u, i
# Out:
# (array([18.99 , 18.987, 18.981, 18.962, 18.905, 18.812, 18.627, 18.095,
#         17.273, 15.833, 12.667,  9.5  ]),
#  array([1.8990e-03, 2.5316e-03, 3.7962e-03, 7.5848e-03, 1.8905e-02,
#         3.7624e-02, 7.4508e-02, 1.8095e-01, 3.4546e-01, 6.3332e-01,
#         1.2667e+00, 1.9000e+00]))

# %%
plt.plot(i, u)
plt.plot(0, 19, 'go')
plt.plot(3.8328, 0, 'go')
plt.grid()
plt.ylabel('U, V')
plt.xlabel('I, A')
# Out:
# Text(0.5, 0, 'I, A')

# %%
p = np.array([0.04, 0.05, 0.07, 0.14, 0.36, 0.71, 1.39, 3.27, 5.97, 10.03, 16.05, 18.05])

# %%
plt.plot(i[:12], p)
plt.grid()
plt.ylabel('P, W')
plt.xlabel('I, A')
# Out:
# Text(0.5, 0, 'I, A')

# %%
mu = np.array([0.99950, 0.99934, 0.99901, 0.99802, 0.99507, 0.99018, 0.98056, 0.95277, 0.90980, 0.83452, 0.66857, 0.50215])

# %%
plt.plot(i[:12], mu)
plt.grid()
plt.ylabel('kpd')
plt.xlabel('I, A')
# Out:
# Text(0.5, 0, 'I, A')
